# %% [markdown]
# <a href="https://colab.research.google.com/github/matpaol/MAOH/blob/main/esercitazioni/prova_cartella.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#file di prova per vedere dove lo salva..

ciao= str(input(f'saluta!'))
if ciao == 'daje_roma':
  print('forza maggica')
else:
  print('laziale di merda!')
# Out:
# saluta!ciao
# laziale di merda!
